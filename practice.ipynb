# %%
if  mystring == "hello":
    print ("String: %s" % mystring)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a754e3db7a36> in <module>
# ----> 1 if  mystring == "hello":
#       2     print ("String: %s" % mystring)
#
# NameError: name 'mystring' is not defined

# %%
data=xlrd.open_workbook(r"C:\Users\Peter123\Desktop.xlsx")

# %%
def read_excel(): dataset = xlrd.open_workbook(dataset=file)#打開文件
print(dataset.sheet_names())#獲取所有表格名字

# %%
f = open(r'C:\Users\Peter123\Desktop\Python_reading.txt')

# %%
f =(r' C:\Users\Peter123\Desktop\data.txt')
text = []
for line in f:
    text.append(line)
    print(text)

# %%
f =open(r'C:\Users\Peter123\Desktop\data.txt')
text = []
for line in f:
    text.append(line)
    print(text)

# %%
A=[[3,4],[2,1]]
B=np.array([2400,1000])
x=(100,None)
y=(0,450)
res=linprog(c,A,B,bounds(x,y))
print(res)

# %%
A=[[3,4],[2,1]]
B=np.array([2400,1000])
x=(100,None)
y=(0,450)
res=linprog(c,A,B,bounds(x,y))
print(res)

# %%
from scipy.optimize import linprog
C = [-1,4] 
A = [[-3,1],[1,2]]
b = [6,4]
X0_bounds = [None,None]
X1_bounds = [-3,None]
res = linprog(C,A,b,bounds=(X0_bounds,X1_bounds))
print(res)

# %%
from scipy.optimize import linprog
C = [0.1,0.15] 
A = [[5,10],[4,3]]
b = [45,24]
X0_bounds = [3,None]
X1_bounds = [0,None]
X2_bounds = [0,None]
res = linprog(C,A,b,bounds=(X0_bounds,X1_bounds,X2_bounds))
print(res)

# %%
from scipy.optimize import linprog
import numpy as np
C = [0.1,0.15] 
A = [[5,10],[4,3]]
b = np.array([45,24])
X0_bounds = [3,None]
X1_bounds = [0,None]
X2_bounds = [0,None]
res = linprog(C,A,b,bounds=(X0_bounds,X1_bounds,X2_bounds))
print(res)

# %%
import numpy as np
A=[[3,4],[2,1]]
B=np.array([2400,1000])
x=(100,None)
y=(0,450)
res=linprog(c,A,B,bounds=(x,y))
print(res)

# %%
from scipy.optimize import linprog
import numpy as np
C = [0.1,0.15] 
A = [[5,10],[4,3]]
b = np.array([45,24])
X0_bounds = [3,None]
X1_bounds = [0,None]
X2_bounds = [0,None]
res = linprog(C,A,b,bounds=(X0_bounds,X1_bounds,X2_bounds))
print(res)

# %%
from scipy.optimize import linprog
import numpy as np
C = [0.1,0.15] 
A = [[5,10],[4,3]]
b = np.array([45,24])
X0_bounds = [3,None]
X1_bounds = [0,None]
X2_bounds = [0,None]
res = linprog(C,A,b,bounds=(X0_bounds,X1_bounds,X2_bounds))
print(res)

# %%
from scipy.optimize import linprog
import numpy as np
C = [0.1,0.15] 
A = [[5,10],[4,3]]
b = np.array([45,24])
X0_bounds = [3,None]
X1_bounds = [0,None]
X2_bounds = [0,None]
res = linprog(C,A,b,bounds=(X0_bounds,X1_bounds,X2_bounds))
print(res)
lb = np.zeros(6) #lower bound for x array
ub = np.ones(6)*2 #upper bound for x array
res2 = linprog(c, A_ub, b_ub, bounds=list(zip(lb, ub)))

# %%
import numpy as np
A=[[3,4],[2,1]]
B=np.array([2400,1000])
x=(100,None)
y=(0,450)
res=linprog(A,B,bounds=(x,y))
print(res)

# %%
import numpy as np
A=[[3,4],[2,1]]
B=np.array([2400,1000])
x=(100,None)
y=(0,450)
res=linprog(c,A,B,bounds=(x,y))
print(res)

# %%
import numpy as np
A=[[3,4],[2,1]]
B=np.array([2400,1000])
x=(100,None)
y=(0,450)
res=linprog(C,A,B,bounds=(x,y))
print(res)

# %%
c=[-7,-5]
import numpy as np
A=[[3,4],[2,1]]
B=np.array([2400,1000])
x=(100,None)
y=(0,450)
res=linprog(C,A,B,bounds=(x,y))
print(res)

# %%
c=[-7,-5]
import numpy as np
A=[[3,4],[2,1]]
B=np.array([2400,1000])
x=(100,None)
y=(0,450)
res=linprog(c,A,B,bounds=(x,y))
print(res)

# %%
from scipy.optimize import linprog
import numpy as np
C = [0.1,0.15] 
A = [[5,10],[4,3]]
B = np.array([45,24])
y = [3,None]
res = linprog(C,A,B,bounds=(y))
print(res)
lb = np.zeros(6) #lower bound for x array
ub = np.ones(6)*2 #upper bound for x array
res2 = linprog(c, A_ub, b_ub, bounds=list(zip(lb, ub)))

# %%
from scipy.optimize import linprog
import numpy as np
C = [0.1,0.15] 
A = [[5,10],[4,3]]
B = np.array([45,24])
y = [3,None]
res = linprog(C,A,B,bounds=(y))
print(res)

# %%
from scipy.optimize import linprog
import numpy as np
C=[450,600]
A=[[1,1],[150,300]]
B=np.array([2400,45000])
res=linprog(C,A,B)
print(res)

# %%
from scipy.optimize import linprog
import numpy as np
C=[450,600]
A=[[1,1],[150,300]]
B=np.array([2400,45000])
res=linprog(C,A,B)
x = [None,None]
y = [None,None]
print(res)

# %%
from scipy.optimize import linprog
import numpy as np
C=[450,600]
A=[[1,1],[150,300]]
B=np.array([2400,45000])
res=linprog(C,A,B,bounds=(x,y))
x = [None,None]
y = [None,None]
print(res)

# %%
x="Today is Saturday."
x.find("is")

# %%
from scipy.optimize import linprog
import numpy as np
C=[90,100]
A=[[1000,1500],[500,400]]
B=np.array([6000,2000])
res=linprog(C,A,B,bounds=(x,y))
x = [None,None]
y = [None,None]
print(res)

# %%
from scipy.optimize import linprog
import numpy as np
C = [0.10,0.15] 
A = [[5,10],[4,3]]
B = np.array([45,24])
y = [3,None]
res = linprog(C,A,B,bounds=(y))
print(res)

# %%
number=eval(input("請輸入數字:"))
if number%2==0:
    print("偶數")
else:
    print("奇數")

# %%
number=eval(input("請輸入數字:"))
if number%2==0:
    print("偶數")
else:
    print("奇數")

# %%
for i in range(5):
    print("*"*2)
print()
# Out:
# **
# **
# **
# **
# **

# %%
i=0
while i<5:
    print(i)
    i=i+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
import  random
num=random.randint(1,100)
answer=-1
while answer!=num:
    answer=eval(input("請猜數字(1~100:)"))
    if answer>num:
        print("太大")
    elif answer<num:
            print("太小")
    else:
                print("猜對了")
# Out:
# 請猜數字(1~100:)50
# 太大
# 請猜數字(1~100:)40
# 太大
# 請猜數字(1~100:)9
# 太小
# 請猜數字(1~100:)35
# 太小
# 請猜數字(1~100:)30
# 太小
# 請猜數字(1~100:)39
# 猜對了

# %%
import numpy as T1
import matplotlib.pyplot as T2
x=T1.array([1,2,3,4,5])
y=x*2
T2.plot(x,y,"r",label="temple")
T2.legend()
T2.show()

# %%
from cm_plot import *
def cm_plot(y, yp):
  from sklearn.metrics import confusion_matrix #匯入混淆矩陣函式
  cm = confusion_matrix(y, yp) #混淆矩陣
  import matplotlib.pyplot as plt #匯入作相簿
  plt.matshow(cm, cmap=plt.cm.Greens) #畫混淆矩陣圖，配色風格使用cm.Greens，更多風格請參考官網。
  plt.colorbar() #顏色標籤
  for x in range(len(cm)): #資料標籤
    for y in range(len(cm)):
      plt.annotate(cm[x,y], xy=(x, y), horizontalalignment='center', verticalalignment='center')
  plt.ylabel('True label') #座標軸標籤
  plt.xlabel('Predicted label') #座標軸標籤
  return plt

import pandas as pd #匯入資料分析庫
from random import shuffle #匯入隨機函式shuffle，用來打散資料
datafile = '資料科學資料集.xlsx' #資料(如圖-2所示)
df = pd.read_excel("資料科學資料集.xlsx")  #讀取資料，資料的前三列是特徵，第四列是標籤,'1'表示竊漏電,'0'表示沒有竊漏電
data = df.as_matrix() #將表格轉換為矩陣
shuffle(data) #隨機打亂資料

# 把資料的80%用來訓練模型,20%做模型測試和評估,此處用到訓練集-驗證集二劃分
p = 0.8 #設定訓練資料比例,
train = data[:int(len(data)*p),:] #前80%為訓練集
test = data[int(len(data)*p):,:] #後20%為測試集

#構建CART決策樹模型
from sklearn.tree import DecisionTreeClassifier #匯入決策樹模型
treefile = 'tree.pkl' #模型輸出名字
tree = DecisionTreeClassifier() #建立決策樹模型
tree.fit(train[:,:3], train[:,3]) #訓練得出決策樹模型

#儲存模型
from sklearn.externals import joblib
joblib.dump(tree, treefile)

#用混淆矩陣視覺化函式畫圖
 #匯入混淆矩陣視覺化函式
cm_plot(train[:,:3], tree.predict(train[:,:3])).show() #顯示混淆矩陣視覺化結果如下
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-46-3e5d890b7328> in <module>
# ----> 1 from cm_plot import *
#       2 def cm_plot(y, yp):
#       3   from sklearn.metrics import confusion_matrix #匯入混淆矩陣函式
#       4   cm = confusion_matrix(y, yp) #混淆矩陣
#       5   import matplotlib.pyplot as plt #匯入作相簿
#
# ModuleNotFoundError: No module named 'cm_plot'

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)
y_pred ='研究經驗'
y_true ='錄取率'
confmat = confusion_matrix(y_true='錄取率', y_pred='研究經驗')
fig, ax = plt.subplots(figsize=(2.5, 2.5))
ax.matshow(confmat, cmap=plt.cm.Blues, alpha=0.3)
for i in range(confmat.shape[0]):
    for j in range(confmat.shape[1]):
        ax.text(x=j, y=i, s=confmat[i,j], va='center', ha='center')
plt.xlabel('predicted label')        
plt.ylabel('true label')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-9a28b9ad6497> in <module>
#       3 y_pred ='研究經驗'
#       4 y_true ='錄取率'
# ----> 5 confmat = confusion_matrix(y_true='錄取率', y_pred='研究經驗')
#       6 fig, ax = plt.subplots(figsize=(2.5, 2.5))
#       7 ax.matshow(confmat, cmap=plt.cm.Blues, alpha=0.3)
#
# D:\Anaconda\lib\site-packages\sklearn\metrics\classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     254     if y_type not in ("binary", "multiclass"):
#     255         raise ValueError("%s is not supported" % y_type)
#
# D:\Anaconda\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      69     y_pred : array or indicator matrix
#      70     """
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import load_model
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_excel("資料科學資料集.xlsx")     
df.head()
# Out:
#    編碼  GRE 分數  TOEFL 分數  大學排名  讀書計畫明確度  推薦信強度  加權平均  研究經驗  錄取機會
# 0   1     337       118     4      4.5    4.5  9.65     1  0.92
# 1   2     324       107     4      4.0    4.5  8.87     1  0.76
# 2   3     316       104     3      3.0    3.5  8.00     1  0.72
# 3   4     322       110     3      3.5    2.5  8.67     1  0.80
# 4   5     314       103     2      2.0    3.0  8.21     0  0.65

# %%
df=pd.read_excel("資料科學資料集.xlsx")#更改索引直
df.set_index("編碼" , inplace=True)
df
# Out:
#      GRE 分數  TOEFL 分數  大學排名  讀書計畫明確度  推薦信強度  加權平均  研究經驗  錄取機會
# 編碼
# 1       337       118     4      4.5    4.5  9.65     1  0.92
# 2       324       107     4      4.0    4.5  8.87     1  0.76
# 3       316       104     3      3.0    3.5  8.00     1  0.72
# 4       322       110     3      3.5    2.5  8.67     1  0.80
# 5       314       103     2      2.0    3.0  8.21     0  0.65
# ..      ...       ...   ...      ...    ...   ...   ...   ...
# 396     324       110     3      3.5    3.5  9.04     1  0.82
# 397     325       107     3      3.0    3.5  9.11     1  0.84
# 398     330       116     4      5.0    4.5  9.45     1  0.91
# 399     312       103     3      3.5    4.0  8.78     0  0.67
# 400     333       117     4      5.0    4.0  9.66     1  0.95
#
# [400 rows x 8 columns]

# %%
df.mean()
# Out:
# GRE 分數      316.807500
# TOEFL 分數    107.410000
# 大學排名          3.087500
# 讀書計畫明確度       3.400000
# 推薦信強度         3.452500
# 加權平均          8.598925
# 研究經驗          0.547500
# 錄取機會          0.724350
# dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d9793dd307d0> in <module>
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 rfc=RandomForestClassifier(n_estimators=5)
# ----> 3 rfc.fit(X_train,y_train)
#
# NameError: name 'X_train' is not defined

# %%
"Hello world".replace("l","!")
# Out:
# 'He!!o wor!d'

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import load_model
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_excel("資料科學資料集.xlsx")     
df.shape
# Out:
# (400, 9)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_excel("資料科學資料集.xlsx")     
data = df[1:,1:].astype(np.float)#讀取數據
df = pd.DataFrame(data[0:,:7]) #將前7個欄位做一次分群

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)  # 分X群
kmeans.fit(df)
y_pred = kmeans.fit_predict(df)  # 將群分類


df = pd.DataFrame({'x':y_pred,'y':data[0:,7]})#在和錄取率做分群
y_pred = kmeans.fit_predict(df)  # 將群分類
centroids = kmeans.cluster_centers_  # 各群中心點(X,Y)的位置
plt.figure(figsize=(10, 6))
plt.ylabel('Chance of Admit ')
plt.xlabel('cluster')
plt.xticks(range(len(y_pred)))#設定為整數
plt.scatter(df.values['x'],df['y'], c=y_pred) #C是第三維度 顏色做維度
plt.scatter(centroids[:, 0], centroids[:, 1],c='red') #標群心
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-b55223f8f40a> in <module>
#       3 import matplotlib.pyplot as plt
#       4 df = pd.read_excel("資料科學資料集.xlsx")
# ----> 5 data = df[1:,1:].astype(np.float)#讀取數據
#       6 df = pd.DataFrame(data[0:,:7]) #將前7個欄位做一次分群
#       7
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 )
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
from sklearn import cluster, datasets, metrics
plt.style.use('ggplot')
# %matplotlib inline
df = pd.read_excel("資料科學資料集.xlsx")
X = df[['研究經驗','錄取機會']].values
km = KMeans(n_clusters=2)  #K=4群
y_pred = km.fit_predict(X)
plt.figure(figsize=(10, 6))
plt.title("研究經驗和錄取率分群")
plt.xlabel('research  experience')
plt.ylabel('rating')
plt.scatter(X[:, 0], X[:, 1], c=y_pred) #C是第三維度 已顏色做維度
km.cluster_centers_ #各群中心點(X,Y)的位置
df
# Out:
#       編碼  GRE 分數  TOEFL 分數  大學排名  讀書計畫明確度  推薦信強度  加權平均  研究經驗  錄取機會
# 0      1     337       118     4      4.5    4.5  9.65     1  0.92
# 1      2     324       107     4      4.0    4.5  8.87     1  0.76
# 2      3     316       104     3      3.0    3.5  8.00     1  0.72
# 3      4     322       110     3      3.5    2.5  8.67     1  0.80
# 4      5     314       103     2      2.0    3.0  8.21     0  0.65
# ..   ...     ...       ...   ...      ...    ...   ...   ...   ...
# 395  396     324       110     3      3.5    3.5  9.04     1  0.82
# 396  397     325       107     3      3.0    3.5  9.11     1  0.84
# 397  398     330       116     4      5.0    4.5  9.45     1  0.91
# 398  399     312       103     3      3.5    4.0  8.78     0  0.67
# 399  400     333       117     4      5.0    4.0  9.66     1  0.95
#
# [400 rows x 9 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc  ###计算roc和auc
#from sklearn import cross_validation
from sklearn.model_selection import cross_validate
df = pd.read_excel("資料科學資料集.xlsx")

X = df.data
y = df.target
X, y = X[y != 2], y[y != 2]
 
# Add noisy features to make the problem harder
random_state = np.random.RandomState(0)
n_samples, n_features = X.shape
X = np.c_[X, random_state.randn(n_samples, 200 * n_features)]
 
# shuffle and split training and test sets
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=.3,random_state=0)
 
# Learn to predict each class against the other
svm = svm.SVC(kernel='linear', probability=True,random_state=random_state)
 
###通过decision_function()计算得到的y_score的值，用在roc_curve()函数中
y_score = svm.fit(X_train, y_train).decision_function(X_test)
 
# Compute ROC curve and ROC area for each class
fpr,tpr,threshold = roc_curve(y_test, y_score) ###计算真正率和假正率
roc_auc = auc(fpr,tpr) ###计算auc的值
 
plt.figure()
lw = 2
plt.figure(figsize=(10,10))
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc) ###假正率为横坐标，真正率为纵坐标做曲线
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-ab80d07a6d18> in <module>
#       8 df = pd.read_excel("資料科學資料集.xlsx")
#       9
# ---> 10 X = df.data
#      11 y = df.target
#      12 X, y = X[y != 2], y[y != 2]
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
from sklearn.metrics import confusion_matrix    # 生成混淆矩阵函数
import matplotlib.pyplot as plt    # 绘图库
import numpy as np
import tensorflow as tf


def plot_confusion_matrix(cm, labels_name, title):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]    # 归一化
    plt.imshow(cm, interpolation='nearest')    # 在特定的窗口上显示图像
    plt.title(title)    # 图像标题
    plt.colorbar()
    num_local = np.array(range(len(labels_name)))    
    plt.xticks(num_local, labels_name, rotation=90)    # 将标签印在x轴坐标上
    plt.yticks(num_local, labels_name)    # 将标签印在y轴坐标上
    plt.ylabel('True label')    
    plt.xlabel('Predicted label')

    
    
pred_y = df(tf.argmax(y_, 1), feed_dict={X: test_x})
cm = confusion_matrix(np.argmax(test_y, 1), pred_y,)
print(cm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-705408798163> in <module>
#      18
#      19
# ---> 20 pred_y = df(tf.argmax(y_, 1), feed_dict={X: test_x})
#      21 cm = confusion_matrix(np.argmax(test_y, 1), pred_y,)
#      22 print(cm)
#
# NameError: name 'y_' is not defined

# %%
import warnings
from collections import OrderedDict
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', 1000)
warnings.filterwarnings('ignore')
df2=pd.read_excel("資料科學資料集.xlsx",encoding="big5")
df3=df2[['GRE 分數','TOEFL 分數','大學排名','讀書計畫明確度','推薦信強度','加權平均','研究經驗','錄取機會']]
df3.head()
exam_X=df3[['GRE 分數','TOEFL 分數','大學排名','讀書計畫明確度','推薦信強度','加權平均','研究經驗']]
exam_y=df3[['錄取機會']]

for i in exam_y:
    exam_y.loc[ exam_y[i]>=0.6,i]=1
    exam_y.loc[ exam_y[i]<0.6,i]=0
#print(exam_y)

examDict=df3
examOrderedDict=OrderedDict(examDict)
examDf=pd.DataFrame(examOrderedDict)
examDf.head()
examDf.describe()
from sklearn.model_selection  import train_test_split
train_X,test_X,train_y,test_y =train_test_split(exam_X,exam_y,train_size=0.8)
print('訓練集大小',train_X.shape,train_y.shape)
print('測試集大小',test_X.shape,test_y.shape)
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(train_X,train_y)
print('模型得分為',round(model.score(test_X,test_y),4))
rDf=examDf.corr()
print(rDf)
# Out:
# 訓練集大小 (320, 7) (320, 1)
# 測試集大小 (80, 7) (80, 1)
# 模型得分為 0.2137
#             GRE 分數  TOEFL 分數      大學排名   讀書計畫明確度     推薦信強度      加權平均      研究經驗      錄取機會
# GRE 分數    1.000000  0.835977  0.668976  0.612831  0.557555  0.833060  0.580391  0.802610
# TOEFL 分數  0.835977  1.000000  0.695590  0.657981  0.567721  0.828417  0.489858  0.791594
# 大學排名      0.668976  0.695590  1.000000  0.734523  0.660123  0.746479  0.447783  0.711250
# 讀書計畫明確度   0.612831  0.657981  0.734523  1.000000  0.729593  0.718144  0.444029  0.675732
# 推薦信強度     0.557555  0.567721  0.660123  0.729593  1.000000  0.670211  0.396859  0.669889
# 加權平均      0.833060  0.828417  0.746479  0.718144  0.670211  1.000000  0.521654  0.873289
# 研究經驗      0.580391  0.489858  0.447783  0.444029  0.396859  0.521654  1.000000  0.553202
# 錄取機會      0.802610  0.791594  0.711250  0.675732  0.669889  0.873289  0.553202  1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
from sklearn import cluster, datasets, metrics
plt.style.use('ggplot')
# %matplotlib inline
df = pd.read_excel("資料科學資料集.xlsx")
X = df[['研究經驗','錄取機會']].values
km = KMeans(n_clusters=3)
kmeans.fit(df)
df = pd.DataFrame({'x':y_pred,'y':data[0:,7]})
y_pred = km.fit_predict(df)

plt.figure(figsize=(10, 6))
plt.title("研究經驗和錄取率分群")
plt.xlabel('research  experience')
plt.ylabel('rating')
plt.scatter(X[:, 0], X[:, 1], c=y_pred) #C是第三維度 已顏色做維度
plt.show()
km.cluster_centers_ #各群中心點(X,Y)的位置
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-418b92cf4806> in <module>
#       9 X = df[['研究經驗','錄取機會']].values
#      10 km = KMeans(n_clusters=3)
# ---> 11 kmeans.fit(df)
#      12 df = pd.DataFrame({'x':y_pred,'y':data[0:,7]})
#      13 y_pred = km.fit_predict(df)
#
# NameError: name 'kmeans' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
from sklearn import cluster, datasets, metrics
plt.style.use('ggplot')
# %matplotlib inline
df = pd.read_excel("資料科學資料集.xlsx")
X = df[['推薦信強度','錄取機會']].values
km = KMeans(n_clusters=2)  #K=4群
y_pred = km.fit_predict(X)
plt.figure(figsize=(10, 6))
plt.xlabel('推薦信強度')
plt.ylabel('錄取機會')
plt.scatter(X[:, 0], X[:, 1], c=y_pred) #C是第三維度 已顏色做維度
plt.show()
km.cluster_centers_ #各群中心點(X,Y)的位置
df
# Out:
#       編碼  GRE 分數  TOEFL 分數  大學排名  讀書計畫明確度  推薦信強度  加權平均  研究經驗  錄取機會
# 0      1     337       118     4      4.5    4.5  9.65     1  0.92
# 1      2     324       107     4      4.0    4.5  8.87     1  0.76
# 2      3     316       104     3      3.0    3.5  8.00     1  0.72
# 3      4     322       110     3      3.5    2.5  8.67     1  0.80
# 4      5     314       103     2      2.0    3.0  8.21     0  0.65
# ..   ...     ...       ...   ...      ...    ...   ...   ...   ...
# 395  396     324       110     3      3.5    3.5  9.04     1  0.82
# 396  397     325       107     3      3.0    3.5  9.11     1  0.84
# 397  398     330       116     4      5.0    4.5  9.45     1  0.91
# 398  399     312       103     3      3.5    4.0  8.78     0  0.67
# 399  400     333       117     4      5.0    4.0  9.66     1  0.95
#
# [400 rows x 9 columns]

# %%
df.boxplot()
df
# Out:
#       編碼  GRE 分數  TOEFL 分數  大學排名  讀書計畫明確度  推薦信強度  加權平均  研究經驗  錄取機會
# 0      1     337       118     4      4.5    4.5  9.65     1  0.92
# 1      2     324       107     4      4.0    4.5  8.87     1  0.76
# 2      3     316       104     3      3.0    3.5  8.00     1  0.72
# 3      4     322       110     3      3.5    2.5  8.67     1  0.80
# 4      5     314       103     2      2.0    3.0  8.21     0  0.65
# ..   ...     ...       ...   ...      ...    ...   ...   ...   ...
# 395  396     324       110     3      3.5    3.5  9.04     1  0.82
# 396  397     325       107     3      3.0    3.5  9.11     1  0.84
# 397  398     330       116     4      5.0    4.5  9.45     1  0.91
# 398  399     312       103     3      3.5    4.0  8.78     0  0.67
# 399  400     333       117     4      5.0    4.0  9.66     1  0.95
#
# [400 rows x 9 columns]
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32232 missing from current font.
# ...

# %%
from sklearn import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
df = pd.read_excel("資料科學資料集.xlsx")
# %matplotlib inline
X_train.astype('int'), X_test, y_train.astype('int'), y_test = train_test_split(
    df[['GRE 分數','TOEFL 分數']], df[['錄取機會']], test_size=0.3, random_state=0)
#train_features = train[['F1','F2','F3','F4','F5','X','Y','Z','C1','C2']]
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(criterion = 'entropy', random_state=0)
tree.fit(X_train,y_train)
# Out:
#   File "<ipython-input-1-7d20a1d1ab9c>", line 9
#     X_train.astype('int'), X_test, y_train.astype('int'), y_test = train_test_split(
#                                                                                     ^
# SyntaxError: can't assign to function call

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_excel("資料科學資料集.xlsx")

df = pd.DataFrame(df[0:,:7]) #將前7個欄位做一次分群
data = tmp[1:,1:].astype(np.float)#讀取數據
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)  # 分X群
kmeans.fit(df)
y_pred = kmeans.fit_predict(df)  # 將群分類


df = pd.DataFrame({'x':y_pred,'y':data[0:,7]})#在和錄取率做分群
y_pred = kmeans.fit_predict(df)  # 將群分類
centroids = kmeans.cluster_centers_  # 各群中心點(X,Y)的位置
plt.figure(figsize=(10, 6))
plt.ylabel('Chance of Admit ')
plt.xlabel('cluster')
plt.xticks(range(len(y_pred)))#設定為整數
plt.scatter(df['x'],df['y'], c=y_pred) #C是第三維度 顏色做維度
plt.scatter(centroids[:, 0], centroids[:, 1],c='red') #標群心
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-3dca9040d1a3> in <module>
#       4 df = pd.read_excel("資料科學資料集.xlsx")
#       5
# ----> 6 df = pd.DataFrame(df[0:,:7]) #將前7個欄位做一次分群
#       7 data = tmp[1:,1:].astype(np.float)#讀取數據
#       8 from sklearn.cluster import KMeans
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 )
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
# ...

# %%
import numpy as np
a = np.array([1,2,3])
b = np.array([2,2,2])
a * b
# Out:
# array([2, 4, 6])

# %%
np.random.randint(4, size=10)
# Out:
# array([3, 0, 0, 3, 2, 0, 1, 3, 3, 3])

# %%
pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import time
import json
from bs4 import BeautifulSoup

# %%
pip install keras
import  tensorflow as tf
tf._version_
# Out:
#   File "<ipython-input-56-68cb7dfa02fd>", line 1
#     pip install keras
#               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
df = pd.read_excel("空氣品質.xlsx")     
df.head()
# Out:
#        統計期  統計區  總站日數  良好站日數  普通站日數  對敏感族群不健康站日數  對所有族群不健康站日數  非常不健康站日數  危害站日數  AQI>100日數比率
# 0  108年 7月  連江縣    31     25      6            0            0         0      0         0.00
# 1  108年 7月  金門縣    31     23      8            0            0         0      0         0.00
# 2  108年 7月  嘉義市    31     28      2            1            0         0      0         3.23
# 3  108年 7月  新竹市    31     29      2            0            0         0      0         0.00
# 4  108年 7月  基隆市    31     30      1            0            0         0      0         0.00

# %%
rDf=df.corr()
print('訓練集大小',train_X.shape,train_y.shape)
print('測試集大小',test_X.shape,test_y.shape)
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(train_X,train_y)
print('模型得分為',round(model.score(test_X,test_y),4))
rDf
# Out:
# 訓練集大小 (70, 804) (70,)
# 測試集大小 (30, 804) (30,)
# 模型得分為 0.2302
#                 編碼    GRE 分數  TOEFL 分數      大學排名   讀書計畫明確度     推薦信強度  \
# 編碼        1.000000 -0.097526 -0.147932 -0.169948 -0.166932 -0.088221
# GRE 分數   -0.097526  1.000000  0.835977  0.668976  0.612831  0.557555
# TOEFL 分數 -0.147932  0.835977  1.000000  0.695590  0.657981  0.567721
# 大學排名     -0.169948  0.668976  0.695590  1.000000  0.734523  0.660123
# 讀書計畫明確度  -0.166932  0.612831  0.657981  0.734523  1.000000  0.729593
# 推薦信強度    -0.088221  0.557555  0.567721  0.660123  0.729593  1.000000
# 加權平均     -0.045608  0.833060  0.828417  0.746479  0.718144  0.670211
# 研究經驗     -0.063138  0.580391  0.489858  0.447783  0.444029  0.396859
# 錄取機會      0.042336  0.802610  0.791594  0.711250  0.675732  0.669889
#
#               加權平均      研究經驗      錄取機會
# 編碼       -0.045608 -0.063138  0.042336
# GRE 分數    0.833060  0.580391  0.802610
# TOEFL 分數  0.828417  0.489858  0.791594
# 大學排名      0.746479  0.447783  0.711250
# ...

# %%
pima-indians-diabetes.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-521eebc385e0> in <module>
# ----> 1 pima-indians-diabetes.csv
#
# NameError: name 'pima' is not defined

# %%
import pandas as pd#資料取得
seriesObj = pd.Series(range(10),index=['a', 'a', 'b', 'b', 'b','c','c','c','c','c'])
seriesObj['c']
# Out:
# c    5
# c    6
# c    7
# c    8
# c    9
# dtype: int64

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set()
uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(uniform_data)

# %%
％matplotlib inline 
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np 
from keras.utils import to_categorical 
from keras import keras import models 
from keras import layers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-eddeecbfe61b> in <module>
#       1 from sklearn.linear_model  import LogisticRegression
#       2 lr=LogisticRegression()
# ----> 3 lr.fit(train_x1,y_shuffle)
#       4 predictions = lr.predict(x_test)
#       5 from sklearn import metrics
#
# NameError: name 'train_x1' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc  ###计算roc和auc
from sklearn.model_selection import cross_validate
from sklearn.model_selection  import train_test_split
 
# Import some data to play with
iris = datasets.load_iris()
X = iris.data
y = iris.target
 
##变为2分类
X, y = X[y != 2], y[y != 2]
 
# Add noisy features to make the problem harder
random_state = np.random.RandomState(0)
n_samples, n_features = X.shape
X = np.c_[X, random_state.randn(n_samples, 200 * n_features)]
 
# shuffle and split training and test sets

train_X,test_X,train_y,test_y =train_test_split(X, y, test_size=.3,random_state=0)
#X_train, X_test, y_train, y_test = cross_validatetrain_test_split(X, y, test_size=.3,random_state=0)
 
# Learn to predict each class against the other
svm = svm.SVC(kernel='linear', probability=True,random_state=random_state)
 
###通过decision_function()计算得到的y_score的值，用在roc_curve()函数中
y_score = svm.fit(X_train, y_train).decision_function(X_test)
 
# Compute ROC curve and ROC area for each class
fpr,tpr,threshold = roc_curve(y_test, y_score) ###计算真正率和假正率
roc_auc = auc(fpr,tpr) ###计算auc的值
 
plt.figure()
lw = 2
plt.figure(figsize=(10,10))
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc) ###假正率为横坐标，真正率为纵坐标做曲线
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-14ae849a6fd1> in <module>
#      28
#      29 ###通过decision_function()计算得到的y_score的值，用在roc_curve()函数中
# ---> 30 y_score = svm.fit(X_train, y_train).decision_function(X_test)
#      31
#      32 # Compute ROC curve and ROC area for each class
#
# NameError: name 'X_train' is not defined
